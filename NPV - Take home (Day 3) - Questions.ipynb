# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="10%">
#             <img src="homework.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Take - home
#                         <br> (Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Let's begin with some hands-on practice exercises.
#
# **Create a dataframe wherever necessary**

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Compute minimum and maximum sales for each store and location
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
# write your code here
import pandas as pd
import numpy as np
df = pd.DataFrame({'Store': ['A', 'B', 'A', 'C', 'D', 'A', 'D', 'A', 'C', 'B'],
 'Location': ['Mumbai', 'Pune', 'Hyderabad', 'Mumbai', 'Pune', 'Delhi', 'Hyderabad', 'Pune', 'Mumbai', 'Pune'],
'Sales': [40000, 45000, 56000, 90000, 89000, 87000, 85000, 78000, 89000, 70000]})
df
# Out:
#   Store   Location  Sales
# 0     A     Mumbai  40000
# 1     B       Pune  45000
# 2     A  Hyderabad  56000
# 3     C     Mumbai  90000
# 4     D       Pune  89000
# 5     A      Delhi  87000
# 6     D  Hyderabad  85000
# 7     A       Pune  78000
# 8     C     Mumbai  89000
# 9     B       Pune  70000

# %%
df['Sales'].min()
# Out:
# 40000

# %%
df['Sales'].max()
# Out:
# 90000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Find duplicate rows based on the column 'Name'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachin</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
# Write your code here
names = ['John','Robert','Aadi','Robert','Robert','Robert','Aadi','Sachin']
salary = [3400,3000,1600,3000,3000,3000,4000,3000]
City = ['Sydney','Chicago','New York','Chicago','Chicago','Texas','London','Chicago']
df1 = pd.DataFrame({'Names':names,'Salary':salary,'City':City})
df1
# Out:
#     Names  Salary      City
# 0    John    3400    Sydney
# 1  Robert    3000   Chicago
# 2    Aadi    1600  New York
# 3  Robert    3000   Chicago
# 4  Robert    3000   Chicago
# 5  Robert    3000     Texas
# 6    Aadi    4000    London
# 7  Sachin    3000   Chicago

# %%
df1[df1.duplicated('Names')]
# Out:
#     Names  Salary     City
# 3  Robert    3000  Chicago
# 4  Robert    3000  Chicago
# 5  Robert    3000    Texas
# 6    Aadi    4000   London

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3.  In column tournament, replace all the 'football' values  with 'cricket' using numpy.where
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
# Write your code here
days = ['Mon','Tues','Wed','Thurs','Fri']
tournament = ['Football','Cricket','Football','Football','Cricket']
df2 = pd.DataFrame({'Days':days,'Tournament':tournament})
df2
# Out:
#     Days Tournament
# 0    Mon   Football
# 1   Tues    Cricket
# 2    Wed   Football
# 3  Thurs   Football
# 4    Fri    Cricket

# %%
df2["Tournament"].replace({'Football':'Cricket'},inplace = True)
df2
# Out:
#     Days Tournament
# 0    Mon    Cricket
# 1   Tues    Cricket
# 2    Wed    Cricket
# 3  Thurs    Cricket
# 4    Fri    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Get the descriptive statistics of the sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# Write your code here
df_sales = pd.DataFrame({
"Name":['John', 'Robert', 'Jonny', 'Mia',"Edward","Thomas","Ethan","Olivia","Arun","Anika","Paulo"]
,"City":["New York","Chicago","Texas"," California","Sydney","New York","Chicago","Sydney","California","Texas","Chicago"]
,"Sales":[60000,42000,50000,24000,12000,82000,59000,85000,97000,35000,47000]
,"Expenses":[12000,33000,40000,34000,28000,19000,32000,10000,49000,34000,55000]})
df_sales
# Out:
#       Name         City  Sales  Expenses
# 0     John     New York  60000     12000
# 1   Robert      Chicago  42000     33000
# 2    Jonny        Texas  50000     40000
# 3      Mia   California  24000     34000
# 4   Edward       Sydney  12000     28000
# 5   Thomas     New York  82000     19000
# 6    Ethan      Chicago  59000     32000
# 7   Olivia       Sydney  85000     10000
# 8     Arun   California  97000     49000
# 9    Anika        Texas  35000     34000
# 10   Paulo      Chicago  47000     55000

# %%
df_sales.describe()
# Out:
#               Sales      Expenses
# count     11.000000     11.000000
# mean   53909.090909  31454.545455
# std    26246.731398  13988.306805
# min    12000.000000  10000.000000
# 25%    38500.000000  23500.000000
# 50%    50000.000000  33000.000000
# 75%    71000.000000  37000.000000
# max    97000.000000  55000.000000

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Create a new column age with values of your choice. And append it to the below dataframe.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Maths</th>
# <th>Science</th>
# <th>English</th>
# </tr>
# <tr>
# <td>Emma</td>
# <td>56</td>
# <td>89</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>78</td>
# <td>87</td>
# <td>89</td>
# </tr>
# <tr>
# <td>Sophia</td>
# <td>78</td>
# <td>78</td>
# <td>76</td>
# </tr>
# <tr>
# <td>James</td>
# <td>67</td>
# <td>89</td>
# <td>78</td>
# </tr>
# <td>John</td>
# <td>88</td>
# <td>78</td>
# <td>87</td>
# </tr>
#
# </table>

# %%
# Write your code here
names = ['Emma','Mia','Sophia','James','John']
Maths = [56,78,78,67,88]
science = [89,87,78,89,78]
English = [89,89,76,78,87]
df3 = pd.DataFrame({'Name':names,'Maths':Maths,'Science':science,'English':English})
df3
# Out:
#      Name  Maths  Science  English
# 0    Emma     56       89       89
# 1     Mia     78       87       89
# 2  Sophia     78       78       76
# 3   James     67       89       78
# 4    John     88       78       87

# %%
df3['Age'] = [22,23,24,20,22]
df3
# Out:
#      Name  Maths  Science  English  Age
# 0    Emma     56       89       89   22
# 1     Mia     78       87       89   23
# 2  Sophia     78       78       76   24
# 3   James     67       89       78   20
# 4    John     88       78       87   22

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Perform right join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#         <td>Geography</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#         <td>History</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>105</td>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
# Write your code here
df1 = pd.DataFrame({'Stud_ID':range(101,106),'Name':['Alex','Amy','Allen','Alice','James'],'MA(Hons)':['History','English','Geography','German','History']})
df1
# Out:
#    Stud_ID   Name   MA(Hons)
# 0      101   Alex    History
# 1      102    Amy    English
# 2      103  Allen  Geography
# 3      104  Alice     German
# 4      105  James    History

# %%
df2 = pd.DataFrame({'Stud_ID':range(101,106),'Res_City':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['English','History','Fine Arts','German','History']})
df2
# Out:
#    Stud_ID   Res_City   MA(Hons)
# 0      101      Delhi    English
# 1      102     Mumbai    History
# 2      103      Delhi  Fine Arts
# 3      104    Chennai     German
# 4      105  Hyderabad    History

# %%
pd.merge(df1,df2, on = ['Stud_ID','MA(Hons)'], how = 'right')
# Out:
#    Stud_ID   Name   MA(Hons)   Res_City
# 0      101    NaN    English      Delhi
# 1      102    NaN    History     Mumbai
# 2      103    NaN  Fine Arts      Delhi
# 3      104  Alice     German    Chennai
# 4      105  James    History  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Using the dataframes created in question 6, perform inner join to combine values based on the columns 'MA(Hons)' and 'Stud_ID' in the two dataframes
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Write your code here
pd.merge(df1,df2, on = ['Stud_ID','MA(Hons)'], how = 'inner')
# Out:
#    Stud_ID   Name MA(Hons)   Res_City
# 0      104  Alice   German    Chennai
# 1      105  James  History  Hyderabad

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8. Concatenate two dataframes along the columns
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
#     <tr>
#         <th>Stud_ID</th>
#         <th>Name</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Alex</td>
#     </tr>
#     <tr>
#         <td>102</td>
#         <td>Amy</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Allen</td>
#     <tr>
#         <td>104</td>
#         <td>Alice</td>
#     </tr>
#         <td>105</td>
#         <td>James</td>
#     </tr>
# </table>
# <br>
#
#
#
# <table>
#     <tr>
#         <th>Res_City</th>
#         <th>MA(Hons)</th>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>English</td>
#     </tr>
#     <tr>
#         <td>Mumbai</td>
#         <td>History</td>
#     </tr>
#     <tr>
#         <td>Delhi</td>
#         <td>Fine Arts</td>
#     </tr>
#     <tr>
#         <td>Chennai</td>
#         <td>German</td>
#     </tr>
#         <td>Hyderabad</td>
#         <td>History</td>
#     </tr>
# </table>

# %%
# Write your code here

# %%
df1 = pd.DataFrame({'Stud_ID':range(101,106),'Name':['Alex','Amy','Allen','Alice','James']})
df1
# Out:
#    Stud_ID   Name
# 0      101   Alex
# 1      102    Amy
# 2      103  Allen
# 3      104  Alice
# 4      105  James

# %%
df2 = pd.DataFrame({'Res_City':['Delhi','Mumbai','Delhi','Chennai','Hyderabad'],'MA(Hons)':['English','History','Fine Arts','German','History']})
df2
# Out:
#     Res_City   MA(Hons)
# 0      Delhi    English
# 1     Mumbai    History
# 2      Delhi  Fine Arts
# 3    Chennai     German
# 4  Hyderabad    History

# %%
pd.concat([df1,df2],axis = 1)
# Out:
#    Stud_ID   Name   Res_City   MA(Hons)
# 0      101   Alex      Delhi    English
# 1      102    Amy     Mumbai    History
# 2      103  Allen      Delhi  Fine Arts
# 3      104  Alice    Chennai     German
# 4      105  James  Hyderabad    History

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9. Calculate minimum, maximum and average sales for each season
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Month</th>
# <th>Sales</th>
# <th>Seasons</th>
# </tr>
# <tr>
# <td>Jan</td>
# <td>22000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Feb</td>
# <td>27000</td>
# <td>Winter</td>
# </tr>
# <tr>
# <td>Mar</td>
# <td>25000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>Apr</td>
# <td>29000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>May</td>
# <td>35000</td>
# <td>Spring</td>
# </tr>
# <tr>
# <td>June</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>July</td>
# <td>78000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Aug</td>
# <td>67000</td>
# <td>Summer</td>
# </tr>
# <tr>
# <td>Sep</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Oct</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Nov</td>
# <td>56000</td>
# <td>Fall</td>
# </tr>
# <tr>
# <td>Dec</td>
# <td>60000</td>
# <td>Winter</td>
# </tr>
#
# </table>

# %%
# Write your code here
sales = {'Months': ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sep','Oct','Nov','Dec'],
        'Sales': [22000,27000,25000,29000,35000,67000,78000,67000,56000,56000,89000,60000],
         'Seasons': ['Winter','Winter','Spring','Spring','Spring','Summer','Summer','Summer','Fall','Fall','Fall','Winter']
        }
df_sales = pd.DataFrame(sales, columns= ['Months', 'Sales','Seasons'])
df_sales
# Out:
#    Months  Sales Seasons
# 0     Jan  22000  Winter
# 1     Feb  27000  Winter
# 2     Mar  25000  Spring
# 3     Apr  29000  Spring
# 4     May  35000  Spring
# 5    June  67000  Summer
# 6    July  78000  Summer
# 7     Aug  67000  Summer
# 8     Sep  56000    Fall
# 9     Oct  56000    Fall
# 10    Nov  89000    Fall
# 11    Dec  60000  Winter

# %%
pd.pivot_table(df_sales,index = ['Seasons'],values = ['Sales'],aggfunc = np.min)
# Out:
#          Sales
# Seasons
# Fall     56000
# Spring   25000
# Summer   67000
# Winter   22000

# %%
pd.pivot_table(df_sales,index = ['Seasons'],values = ['Sales'],aggfunc = np.max)
# Out:
#          Sales
# Seasons
# Fall     89000
# Spring   35000
# Summer   78000
# Winter   60000

# %%
pd.pivot_table(df_sales,index = ['Seasons'],values = ['Sales'],aggfunc = np.mean)
# Out:
#                 Sales
# Seasons
# Fall     67000.000000
# Spring   29666.666667
# Summer   70666.666667
# Winter   36333.333333

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10. Find all the duplicate entries based on the columns X and Y.
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>X</th>
# <th>Y</th>
# <th>Z</th>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>5</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>3</td>
# <td>1</td>
# <td>2</td>
# </tr>
# <tr>
# <td>1</td>
# <td>2</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>1</td>
# </tr>
# <tr>
# <td>3</td>
# <td>4</td>
# <td>6</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>2</td>
# </tr>
# <tr>
# <td>2</td>
# <td>2</td>
# <td>8</td>
# </tr>
#
# </table>

# %%
# Write your code here
df = pd.DataFrame({'X':[1,2,3,1,2,3,2,2],'Y':[2,2,1,2,2,4,2,2],'Z':[5,6,2,6,1,6,2,8]})
df[df.duplicated(['X','Y'])]
# Out:
#    X  Y  Z
# 3  1  2  6
# 4  2  2  1
# 6  2  2  2
# 7  2  2  8
